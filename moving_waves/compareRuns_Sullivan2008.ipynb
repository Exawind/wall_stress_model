# %% [markdown]
# ### Comparison of nalu-wind data with Sullivan et al. 2008
#
# Data digitized from Sullivan et al. 2008 paper

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %matplotlib inline
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
rcParams.update({'figure.autolayout': True})

# %%
# Peter Sullivan data
sully_path='sullivan_data/'

class profile_sullivan:
    def __init__(self,Filename):
        DATA=np.genfromtxt(Filename,delimiter=',',skip_header=1)
        self.z=DATA[:,0]
        self.U=DATA[:,1]
        self.V=DATA[:,2]
        self.u2=DATA[:,3]
        self.v2=DATA[:,4]
        self.w2=DATA[:,5]

NoWaves=profile_sullivan(sully_path+'NoWaves.dat')
Bumps=profile_sullivan(sully_path+'Bumps.dat')
WindFollowing=profile_sullivan(sully_path+'WindFollowing.dat')
WindOpposing=profile_sullivan(sully_path+'WindOpposing.dat')

# %%
Ug=5
Vg=0.
zi=400.
markS=7
Every=7
plt.figure(11,figsize=(10,7))
ax1=plt.subplot(121)
ax1.plot(NoWaves.U,NoWaves.z,'--k',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax1.plot(Bumps.U,Bumps.z,'-sk',markerfacecolor='none',markersize=markS,markevery=Every,label='Stationary (PS)')
ax1.plot(WindFollowing.U,WindFollowing.z,'-ob',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind following (PS)')
ax1.plot(WindOpposing.U,WindOpposing.z,'-^k',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind opposing (PS)')
ax1.set_ylabel(r'$z/z_i$',fontsize=22)
ax1.set_xlabel(r'$\langle u \rangle/U_g$',fontsize=22)
ax1.set_xticks([0,.5,1.0])
ax1.set_yticks([0.5,1])
ax1.tick_params(labelsize=18)
ax1.set_xlim(0.,1.2)
ax1.set_ylim(0,1)
ax1.legend(fontsize=11,frameon=False)
ax2=plt.subplot(122)
ax2.plot(NoWaves.V,NoWaves.z,'--k',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax2.plot(Bumps.V,Bumps.z,'-sk',markerfacecolor='none',markersize=markS,markevery=Every,label='Stationary (PS)')
ax2.plot(WindFollowing.V,WindFollowing.z,'-ob',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind following (PS)')
ax2.plot(WindOpposing.V,WindOpposing.z,'-^k',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind opposing (PS)')
ax2.set_ylabel(r'$z/z_i$',fontsize=22)
ax2.set_xlabel(r'$\langle v \rangle/U_g$',fontsize=22)
ax2.set_xticks([-0.2,-0.1,0.,0.1,0.2])
ax2.set_yticks([0.5,1])
ax2.tick_params(labelsize=18)
ax2.set_xlim(-0.2,0.25)
ax2.set_ylim(0,1)

markS=7
Every=2
plt.figure(12,figsize=(15,5))
ax1=plt.subplot(131)
ax1.semilogy(NoWaves.u2,NoWaves.z,'--k',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax1.semilogy(Bumps.u2,Bumps.z,'-sk',markerfacecolor='none',markersize=markS,markevery=Every,label='Stationary (PS)')
ax1.semilogy(WindFollowing.u2,WindFollowing.z,'-ob',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind following (PS)')
ax1.semilogy(WindOpposing.u2,WindOpposing.z,'-^k',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind opposing (PS)')
ax1.set_ylabel(r'$z/z_i$',fontsize=22)
ax1.set_xlabel(r'$\langle u^2 \rangle$',fontsize=22)
#ax1.set_xticks([0,.5,1.0])
ax1.set_yticks([0.5,1])
ax1.tick_params(labelsize=18)
#ax1.set_xlim(0.,1.2)
ax1.set_ylim(0.005,1.1)
ax1.legend(fontsize=11,frameon=False)
ax2=plt.subplot(132)
ax2.semilogy(NoWaves.v2,NoWaves.z,'--k',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax2.semilogy(Bumps.v2,Bumps.z,'-sk',markerfacecolor='none',markersize=markS,markevery=Every,label='Stationary (PS)')
ax2.semilogy(WindFollowing.v2,WindFollowing.z,'-ob',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind following (PS)')
ax2.semilogy(WindOpposing.v2,WindOpposing.z,'-^k',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind opposing (PS)')
ax2.set_ylabel(r'$z/z_i$',fontsize=22)
ax2.set_xlabel(r'$\langle v^2 \rangle$',fontsize=22)
#ax2.set_xticks([-0.2,-0.1,0.,0.1,0.2])
ax2.set_yticks([0.5,1])
ax2.tick_params(labelsize=18)
#ax2.set_xlim(-0.2,0.25)
ax2.set_ylim(0.005,1.1)
ax3=plt.subplot(133)
ax3.semilogy(NoWaves.w2,NoWaves.z,'--k',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax3.semilogy(Bumps.w2,Bumps.z,'-sk',markerfacecolor='none',markersize=markS,markevery=Every,label='Stationary (PS)')
ax3.semilogy(WindFollowing.w2,WindFollowing.z,'-ob',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind following (PS)')
ax3.semilogy(WindOpposing.w2,WindOpposing.z,'-^k',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind opposing (PS)')
ax3.set_ylabel(r'$z/z_i$',fontsize=22)
ax3.set_xlabel(r'$\langle w^2 \rangle$',fontsize=22)
#ax3.set_xticks([-0.2,-0.1,0.,0.1,0.2])
ax3.set_yticks([0.5,1])
ax3.tick_params(labelsize=18)
#ax2.set_xlim(-0.2,0.25)
ax3.set_ylim(0.005,1.1)
# Out:
# (0.005, 1.1)

# %% [markdown]
# ## Compare flat-terrain Nalu wind simulations with PP Sullivan data

# %%
Ug=5.
Vg=0.
zi=400.

data_path='flat_terrain_transients/'


class profile_naluwind:
    def __init__(self,Filename):
        DATA=np.genfromtxt(Filename,delimiter=',',skip_header=1)
        self.z=DATA[:,0]
        self.U=DATA[:,1]
        self.V=DATA[:,2]
        self.W=DATA[:,3]
        self.T=DATA[:,4]
        self.u2=DATA[:,5]
        self.uv=DATA[:,6]
        self.uw=DATA[:,7]
        self.v2=DATA[:,8]
        self.vw=DATA[:,9]
        self.w2=DATA[:,10]

flat1=profile_naluwind(data_path+'profile_velocity_200_800.dat')
flat2=profile_naluwind(data_path+'profile_velocity_800_1400.dat')
flat3=profile_naluwind(data_path+'profile_velocity_1400_2000.dat')

utau=np.genfromtxt(data_path+'u_tau.dat',delimiter=',')

plt.figure(20,figsize=(5,3))
ax0=plt.subplot(111)
ax0.plot(utau[:,0],utau[:,1],'k')
ax0.plot(utau[200:800,0],np.average(utau[200:800,1])*np.linspace(1,1,600),'-b')
ax0.plot(utau[800:1400,0],np.average(utau[800:1400,1])*np.linspace(1,1,600),'-g')
ax0.plot(utau[1400:2000,0],np.average(utau[1400:2000,1])*np.linspace(1,1,600),'-r')
ax0.set_ylabel(r'$u_*$ [m/s]',fontsize=22)
ax0.set_xlabel(r'time [s]',fontsize=22)
ax0.set_xticks([0,10000,20000.0,30000,40000,50000,])
ax0.set_yticks([0.13,0.15,0.17,0.19,0.21])
ax0.tick_params(labelsize=18)
ax0.set_xlim(0.,50000)
ax0.set_ylim(0.12,0.17)
plt.savefig("PS2008__flat_u_tau.png",format='png')

markS=7
Every=10
plt.figure(21,figsize=(15,5))
ax1=plt.subplot(131)
ax1.plot(NoWaves.U,NoWaves.z,'ok',markerfacecolor='none',markersize=markS,markevery=Every,label='PS')
ax1.plot(flat1.U/Ug,flat1.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='t=5000-20000')
ax1.plot(flat2.U/Ug,flat2.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='t=20000-35000')
ax1.plot(flat3.U/Ug,flat3.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='t=35000-50000')
ax1.set_ylabel(r'$z/z_i$',fontsize=22)
ax1.set_xlabel(r'$\langle U \rangle/U_g$',fontsize=22)
ax1.set_xticks([0,.5,1.0])
ax1.set_yticks([0.5,1])
ax1.tick_params(labelsize=18)
ax1.set_xlim(0.,1.2)
ax1.set_ylim(0,2)
ax1.legend(fontsize=14,frameon=False)
ax2=plt.subplot(132)
ax2.plot(NoWaves.V,NoWaves.z,'ok',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax2.plot(flat1.V/Ug,flat1.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=5000-20000)')
ax2.plot(flat2.V/Ug,flat2.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=20000-35000)')
ax2.plot(flat3.V/Ug,flat3.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=35000-50000)')
ax2.set_ylabel(r'$z/z_i$',fontsize=22)
ax2.set_xlabel(r'$\langle V \rangle/U_g$',fontsize=22)
ax2.set_xticks([-0.2,-0.1,0.,0.1,0.2])
ax2.set_yticks([0.5,1])
ax2.tick_params(labelsize=18)
ax2.set_xlim(-0.2,0.25)
ax2.set_ylim(0,2)
ax3=plt.subplot(133)
ax3.plot(NoWaves.V,NoWaves.z,'ok',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax3.plot(flat1.T,flat1.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=5000-20000)')
ax3.plot(flat2.T,flat2.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=20000-35000)')
ax3.plot(flat3.T,flat3.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=35000-50000)')
ax3.set_ylabel(r'$z/z_i$',fontsize=22)
ax3.set_xlabel(r'$T$',fontsize=22)
ax3.set_xticks([285,287.5,290,292.5,295])
ax3.set_yticks([0.5,1,1.5,2])
ax3.tick_params(labelsize=18)
ax3.set_xlim(285,295)
ax3.set_ylim(0,2)
plt.savefig("PS2008_flat_means.png",format='png')

Every=1
plt.figure(22,figsize=(15,5))
ax1=plt.subplot(131)
ax1.semilogy(NoWaves.u2,NoWaves.z,'ok',markerfacecolor='none',markersize=markS,markevery=Every,label='PS')
ax1.semilogy(flat1.u2/Ug**2.,flat1.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='t=5000-20000')
ax1.semilogy(flat2.u2/Ug**2.,flat2.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='t=20000-35000')
ax1.semilogy(flat3.u2/Ug**2.,flat3.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='t=35000-50000')
ax1.set_ylabel(r'$z/z_i$',fontsize=22)
ax1.set_xlabel(r'$\langle u^2 \rangle/U_g^2$',fontsize=22)
ax1.set_yticks([0.5,1])
ax1.tick_params(labelsize=18)
ax1.set_ylim(0.003,1)
ax1.legend(fontsize=11,frameon=False)
ax2=plt.subplot(132)
ax2.semilogy(NoWaves.v2,NoWaves.z,'ok',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax2.semilogy(flat1.v2/Ug**2.,flat1.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=5000-20000)')
ax2.semilogy(flat2.v2/Ug**2.,flat2.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=20000-35000)')
ax2.semilogy(flat3.v2/Ug**2.,flat3.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=35000-50000)')
ax2.set_ylabel(r'$z/z_i$',fontsize=22)
ax2.set_xlabel(r'$\langle v^2 \rangle/U_g^2$',fontsize=22)
ax2.set_yticks([0.5,1])
ax2.tick_params(labelsize=18)
ax2.set_ylim(0.003,1)
ax3=plt.subplot(133)
ax3.semilogy(NoWaves.w2,NoWaves.z,'ok',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax3.semilogy(flat1.w2/Ug**2.,flat1.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=5000-20000)')
ax3.semilogy(flat2.w2/Ug**2.,flat2.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=20000-35000)')
ax3.semilogy(flat3.w2/Ug**2.,flat3.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=35000-50000)')
ax3.set_ylabel(r'$z/z_i$',fontsize=22)
ax3.set_xlabel(r'$\langle w^2 \rangle/U_g^2$',fontsize=22)
ax3.set_yticks([0.5,1])
ax3.tick_params(labelsize=18)
ax3.set_ylim(0.003,1)
plt.savefig("PS2008_flat_variances.png",format='png')


duwdz_flat1=np.gradient(flat1.uw,flat1.z,edge_order=2)
duwdz_flat2=np.gradient(flat1.uw,flat2.z,edge_order=2)
duwdz_flat3=np.gradient(flat1.uw,flat3.z,edge_order=2)

dvwdz_flat1=np.gradient(flat1.vw,flat1.z,edge_order=2)
dvwdz_flat2=np.gradient(flat2.vw,flat2.z,edge_order=2)
dvwdz_flat3=np.gradient(flat3.vw,flat3.z,edge_order=2)

f=0.0001

plt.figure(23,figsize=(8,4))
ax1=plt.subplot(121)
ax1.plot(duwdz_flat1-f*flat1.V,flat1.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='t=5000-20000')
ax1.plot(duwdz_flat2-f*flat2.V,flat2.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='t=20000-35000')
ax1.plot(duwdz_flat3-f*flat3.V,flat3.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='t=35000-50000')
ax1.set_ylabel(r'$z/z_i$',fontsize=22)
ax1.set_xlabel(r'$\frac{\mathrm{d} \langle u w  \rangle}{\mathrm{d} z}-f \langle V \rangle)$',fontsize=22)
ax1.set_ylim(0.02,2)
ax1.set_xlim(-0.0005,0.0005)
ax1.legend(fontsize=11,frameon=False)
ax2=plt.subplot(122)
ax2.plot(dvwdz_flat1-f*(Ug-flat1.U),flat1.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=5000-15000)')
ax2.plot(dvwdz_flat2-f*(Ug-flat2.U),flat2.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=15000-25000)')
ax2.plot(dvwdz_flat3-f*(Ug-flat3.U),flat3.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (t=25000-35000)')
ax2.set_ylim(0.02,2)
ax2.set_xlim(-0.0005,0.0005)
ax2.set_ylabel(r'$z/z_i$',fontsize=22)
ax2.set_xlabel(r'$\frac{\mathrm{d} \langle v w  \rangle}{\mathrm{d} z}-f (U_g- \langle U \rangle)$',fontsize=22)
plt.savefig("PS2008_momentum_flux_balance.png",format='png')

# %%
Ug=5.
Vg=0.
zi=400.

class profile_naluwind:
    def __init__(self,Filename):
        DATA=np.genfromtxt(Filename,delimiter=',',skip_header=1)
        self.z=DATA[:,0]
        self.U=DATA[:,1]
        self.V=DATA[:,2]
        self.W=DATA[:,3]
        self.T=DATA[:,4]
        self.u2=DATA[:,5]
        self.uv=DATA[:,6]
        self.uw=DATA[:,7]
        self.v2=DATA[:,8]
        self.vw=DATA[:,9]
        self.w2=DATA[:,10]

flat=profile_naluwind('flat_terrain_transients/profile_velocity_200_800.dat')
bump=profile_naluwind('nalu_data/profile_bump.dat')
wind_following=profile_naluwind('nalu_data/profile_wind_following.dat')

markS=7
Every=10
plt.figure(31,figsize=(10,5))
ax1=plt.subplot(121)
#ax1.plot(NoWaves.U,NoWaves.z,'ob',markerfacecolor='none',markersize=markS,markevery=Every,label='PS (Flat)')
ax1.plot(flat.U/Ug,flat.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='Nalu-wind (Flat)')
#ax1.plot(Bumps.U,Bumps.z,'sg',markerfacecolor='none',markersize=markS,markevery=Every,label='PS (Bumps)')
ax1.plot(bump.U/Ug,bump.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='Nalu-wind (Bumps)')
#ax1.plot(WindFollowing.U,WindFollowing.z,'dr',markerfacecolor='none',markersize=markS,markevery=Every,label='PS (Wind-following)')
ax1.plot(wind_following.U/Ug,wind_following.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='Nalu-wind (Wind-following)')
ax1.set_ylabel(r'$z/z_i$',fontsize=22)
ax1.set_xlabel(r'$\langle U \rangle/U_g$',fontsize=22)
ax1.set_xticks([0,.5,1.0])
ax1.set_yticks([0.5,1])
ax1.tick_params(labelsize=18)
ax1.set_xlim(0.,1.2)
ax1.set_ylim(0,2)
ax1.legend(fontsize=14,frameon=False)
ax2=plt.subplot(122)
#ax2.plot(NoWaves.V,NoWaves.z,'ob',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax2.plot(flat.V/Ug,flat.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat flat')
#ax2.plot(Bumps.V,Bumps.z,'sg',markerfacecolor='none',markersize=markS,markevery=Every,label='PS')
ax2.plot(bump.V/Ug,bump.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat bump')
#ax2.plot(WindFollowing.V,WindFollowing.z,'dr',markerfacecolor='none',markersize=markS,markevery=Every,label='PS')
ax2.plot(wind_following.V/Ug,wind_following.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='wind-following')
ax2.set_ylabel(r'$z/z_i$',fontsize=22)
ax2.set_xlabel(r'$\langle V \rangle/U_g$',fontsize=22)
ax2.set_xticks([-0.2,-0.1,0.,0.1,0.2])
ax2.set_yticks([0.5,1])
ax2.tick_params(labelsize=18)
ax2.set_xlim(-0.2,0.25)
ax2.set_ylim(0,2)
plt.savefig("PS2008_comparison_means.png",format='png')


Every=1
plt.figure(32,figsize=(15,5))
ax1=plt.subplot(131)
#ax1.semilogy(NoWaves.u2,NoWaves.z,'ob',markerfacecolor='none',markersize=markS,markevery=Every,label='PS (Flat)')
ax1.semilogy(flat.u2/Ug**2.,flat.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='Nalu-wind (Flat)')
#ax1.semilogy(Bumps.u2,Bumps.z,'sg',markerfacecolor='none',markersize=markS,markevery=Every,label='PS (Bumps)')
ax1.semilogy(bump.u2/Ug**2.,bump.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='Nalu-wind (Bumps)')
#ax1.semilogy(WindFollowing.u2,WindFollowing.z,'dr',markerfacecolor='none',markersize=markS,markevery=Every,label='PS (Wind-following)')
ax1.semilogy(wind_following.u2/Ug**2.,wind_following.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='Nalu-wind (Wind-following)')
ax1.set_ylabel(r'$z/z_i$',fontsize=22)
ax1.set_xlabel(r'$\langle u^2 \rangle/U_g^2$',fontsize=22)
ax1.set_yticks([0.5,1])
ax1.tick_params(labelsize=18)
ax1.set_ylim(0.003,1)
ax1.legend(fontsize=11,frameon=False)
ax2=plt.subplot(132)
#ax2.semilogy(NoWaves.v2,NoWaves.z,'ob',markerfacecolor='none',markersize=markS,markevery=Every,label='PS (Flat)')
ax2.semilogy(flat.v2/Ug**2.,flat.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='Nalu-wind (Flat)')
#ax2.semilogy(Bumps.v2,Bumps.z,'sg',markerfacecolor='none',markersize=markS,markevery=Every,label='PS (Bumps)')
ax2.semilogy(bump.v2/Ug**2.,bump.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='Nalu-wind (Bumps)')
#ax2.semilogy(WindFollowing.v2,WindFollowing.z,'dr',markerfacecolor='none',markersize=markS,markevery=Every,label='PS (Wind-following)')
ax2.semilogy(wind_following.v2/Ug**2.,wind_following.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='Nalu-wind (Wind-following)')
ax2.set_ylabel(r'$z/z_i$',fontsize=22)
ax2.set_xlabel(r'$\langle v^2 \rangle/U_g^2$',fontsize=22)
ax2.set_yticks([0.5,1])
ax2.tick_params(labelsize=18)
ax2.set_ylim(0.003,1)
ax3=plt.subplot(133)
#ax3.semilogy(NoWaves.w2,NoWaves.z,'ob',markerfacecolor='none',markersize=markS,markevery=Every,label='PS (Flat)')
ax3.semilogy(flat.w2/Ug**2.,flat.z/zi,'-b',markerfacecolor='none',markersize=markS,markevery=Every,label='Nalu-wind (Flat)')
#ax3.semilogy(Bumps.w2,Bumps.z,'sg',markerfacecolor='none',markersize=markS,markevery=Every,label='PS (Bumps)')
ax3.semilogy(bump.w2/Ug**2.,bump.z/zi,'-g',markerfacecolor='none',markersize=markS,markevery=Every,label='Nalu-wind (Bumps)')
#ax3.semilogy(WindFollowing.w2,WindFollowing.z,'dr',markerfacecolor='none',markersize=markS,markevery=Every,label='PS (Wind-following)')
ax3.semilogy(wind_following.w2/Ug**2.,wind_following.z/zi,'-r',markerfacecolor='none',markersize=markS,markevery=Every,label='Nalu-wind (Wind-following)')
ax3.set_ylabel(r'$z/z_i$',fontsize=22)
ax3.set_xlabel(r'$\langle w^2 \rangle/U_g^2$',fontsize=22)
ax3.set_yticks([0.5,1])
ax3.tick_params(labelsize=18)
ax3.set_ylim(0.003,1)
plt.savefig("PS2008_flat_variances.png",format='png')

# %% [markdown]
# ### Comparison of nalu-wind data with Sullivan et al. 2008
#
# Data digitized from Sullivan et al. 2008 paper

# %%
# %%capture
# Import libraries
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
rcParams.update({'figure.autolayout': True})

# %%
# Peter Sullivan data
sully_path='sullivan_data/'

#Compile data

Cases = ['NoWaves','Bumps',]

# %%
Ug=5
Vg=0.
zi=400.
markS=7
plt.figure(1,figsize=(10,7))
ax1=plt.subplot(121)
ax1.plot(U_sullyZN[:,0],U_sullyZN[:,1],'--k',markerfacecolor='none',markersize=markS,markevery=1,label='Flat (PS)')
ax1.plot(U_sullyBN[:,0],U_sullyBN[:,1],'-sk',markerfacecolor='none',markersize=markS,markevery=1,label='Stationary (PS)')
ax1.plot(U_sullyFN[:,0],U_sullyFN[:,1],'-ob',markerfacecolor='none',markersize=markS,markevery=1,label='Wind following (PS)')
ax1.plot(U_sullyON[:,0],U_sullyON[:,1],'-^k',markerfacecolor='none',markersize=markS,markevery=1,label='Wind opposing (PS)')
ax1.plot(U_sullyFC[:,0],U_sullyFC[:,1],'-*k',markerfacecolor='none',markersize=markS,markevery=1,label='Wind following/Conv (PS)')
ax1.set_ylabel(r'$z/z_i$',fontsize=22)
ax1.set_xlabel(r'$\langle u \rangle/U_g$',fontsize=22)
ax1.set_xticks([0,.5,1.0])
ax1.set_yticks([0.5,1])
ax1.tick_params(labelsize=18)
ax1.set_xlim(0.,1.2)
ax1.set_ylim(0,1)
ax1.legend(fontsize=11,frameon=False)
ax2=plt.subplot(122)
ax2.plot(V_sullyZN[:,0],V_sullyZN[:,1],'--k',markerfacecolor='none',markersize=markS,markevery=1,label='Flat (PS)')
ax2.plot(V_sullyBN[:,0],V_sullyBN[:,1],'-sk',markerfacecolor='none',markersize=markS,markevery=1,label='Stationary (PS)')
ax2.plot(V_sullyFN[:,0],V_sullyFN[:,1],'-ob',markerfacecolor='none',markersize=markS,markevery=1,label='Wind following (PS)')
ax2.plot(V_sullyON[:,0],V_sullyON[:,1],'-^k',markerfacecolor='none',markersize=markS,markevery=1,label='Wind opposing (PS)')
ax2.plot(V_sullyFC[:,0],V_sullyFC[:,1],'-*k',markerfacecolor='none',markersize=markS,markevery=1,label='Wind following/Conv (PS)')
ax2.set_ylabel(r'$z/z_i$',fontsize=22)
ax2.set_xlabel(r'$\langle v \rangle/U_g$',fontsize=22)
ax2.set_xticks([-0.2,-0.1,0.,0.1,0.2])
ax2.set_yticks([0.5,1])
ax2.tick_params(labelsize=18)
ax2.set_xlim(-0.2,0.25)
ax2.set_ylim(0,1)
# Out:
# (0, 1)

# %% [markdown]
# ### Comparison of nalu-wind data with Sullivan et al. 2008
#
# Data digitized from Sullivan et al. 2008 paper

# %%
# %%capture
# Import libraries
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
# %matplotlib inline
plt.rc('text',usetex=True)
plt.rc('font',family='serif')
rcParams.update({'figure.autolayout': True})

# %%
# Peter Sullivan data
sully_path='sullivan_data/'

class profile:
    def __init__(self,Filename):
        DATA=np.genfromtxt(Filename,delimiter=',',skip_header=1)
        self.z=DATA[:,0]
        self.U=DATA[:,1]
        self.V=DATA[:,2]
        self.u2=DATA[:,3]
        self.v2=DATA[:,4]
        self.w2=DATA[:,5]

NoWaves=profile(sully_path+'NoWaves.dat')
Bumps=profile(sully_path+'Bumps.dat')
WindFollowing=profile(sully_path+'WindFollowing.dat')
WindOpposing=profile(sully_path+'WindOpposing.dat')

# %%
Ug=5
Vg=0.
zi=400.
markS=7
Every=7
plt.figure(1,figsize=(10,7))
ax1=plt.subplot(121)
ax1.plot(NoWaves.U,NoWaves.z,'--k',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax1.plot(Bumps.U,Bumps.z,'-sk',markerfacecolor='none',markersize=markS,markevery=Every,label='Stationary (PS)')
ax1.plot(WindFollowing.U,WindFollowing.z,'-ob',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind following (PS)')
ax1.plot(WindOpposing.U,WindOpposing.z,'-^k',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind opposing (PS)')
ax1.set_ylabel(r'$z/z_i$',fontsize=22)
ax1.set_xlabel(r'$\langle u \rangle/U_g$',fontsize=22)
ax1.set_xticks([0,.5,1.0])
ax1.set_yticks([0.5,1])
ax1.tick_params(labelsize=18)
ax1.set_xlim(0.,1.2)
ax1.set_ylim(0,1)
ax1.legend(fontsize=11,frameon=False)
ax2=plt.subplot(122)
ax2.plot(NoWaves.V,NoWaves.z,'--k',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax2.plot(Bumps.V,Bumps.z,'-sk',markerfacecolor='none',markersize=markS,markevery=Every,label='Stationary (PS)')
ax2.plot(WindFollowing.V,WindFollowing.z,'-ob',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind following (PS)')
ax2.plot(WindOpposing.V,WindOpposing.z,'-^k',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind opposing (PS)')
ax2.set_ylabel(r'$z/z_i$',fontsize=22)
ax2.set_xlabel(r'$\langle v \rangle/U_g$',fontsize=22)
ax2.set_xticks([-0.2,-0.1,0.,0.1,0.2])
ax2.set_yticks([0.5,1])
ax2.tick_params(labelsize=18)
ax2.set_xlim(-0.2,0.25)
ax2.set_ylim(0,1)
# Out:
# (0, 1)

# %%
plt.figure(2,figsize=(15,5))
ax1=plt.subplot(131)
ax1.plot(NoWaves.u2,NoWaves.z,'--k',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax1.plot(Bumps.u2,Bumps.z,'-sk',markerfacecolor='none',markersize=markS,markevery=Every,label='Stationary (PS)')
ax1.plot(WindFollowing.u2,WindFollowing.z,'-ob',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind following (PS)')
ax1.plot(WindOpposing.u2,WindOpposing.z,'-^k',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind opposing (PS)')
ax1.set_ylabel(r'$z/z_i$',fontsize=22)
ax1.set_xlabel(r'$\langle u^2 \rangle$',fontsize=22)
#ax1.set_xticks([0,.5,1.0])
ax1.set_yticks([0.5,1])
ax1.tick_params(labelsize=18)
#ax1.set_xlim(0.,1.2)
ax1.set_ylim(0,1)
ax1.legend(fontsize=11,frameon=False)
ax2=plt.subplot(132)
ax2.plot(NoWaves.v2,NoWaves.z,'--k',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax2.plot(Bumps.v2,Bumps.z,'-sk',markerfacecolor='none',markersize=markS,markevery=Every,label='Stationary (PS)')
ax2.plot(WindFollowing.v2,WindFollowing.z,'-ob',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind following (PS)')
ax2.plot(WindOpposing.v2,WindOpposing.z,'-^k',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind opposing (PS)')
ax2.set_ylabel(r'$z/z_i$',fontsize=22)
ax2.set_xlabel(r'$\langle v^2 \rangle$',fontsize=22)
#ax2.set_xticks([-0.2,-0.1,0.,0.1,0.2])
ax2.set_yticks([0.5,1])
ax2.tick_params(labelsize=18)
#ax2.set_xlim(-0.2,0.25)
ax2.set_ylim(0,1)
ax3=plt.subplot(133)
ax3.plot(NoWaves.w2,NoWaves.z,'--k',markerfacecolor='none',markersize=markS,markevery=Every,label='Flat (PS)')
ax3.plot(Bumps.w2,Bumps.z,'-sk',markerfacecolor='none',markersize=markS,markevery=Every,label='Stationary (PS)')
ax3.plot(WindFollowing.w2,WindFollowing.z,'-ob',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind following (PS)')
ax3.plot(WindOpposing.w2,WindOpposing.z,'-^k',markerfacecolor='none',markersize=markS,markevery=Every,label='Wind opposing (PS)')
ax3.set_ylabel(r'$z/z_i$',fontsize=22)
ax3.set_xlabel(r'$\langle w^2 \rangle$',fontsize=22)
#ax3.set_xticks([-0.2,-0.1,0.,0.1,0.2])
ax3.set_yticks([0.5,1])
ax3.tick_params(labelsize=18)
#ax2.set_xlim(-0.2,0.25)
ax3.set_ylim(0,1)
# Out:
# (0, 1)
